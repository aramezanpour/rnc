# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def open_file(path = "avE-R11-S8R1-P1.dat"):
    data = []
    with open(path) as f:
        for l in f.readlines():
            line = (l.split())
            if(len(line)>0):
              if(line[0][0]!='#'):
                line = list(map(float, line))
                data.append(line)
    data = np.array(data)
    return data

# %%
E11S8R1P1 = open_file(path = "avE-R11-S8R1-P1.dat")
E11S8R1P2 = open_file(path = "avE-R11-S8R1-P2.dat")
E11S8R1P4 = open_file(path = "avE-R11-S8R1-P4.dat")
E11S8R1P6 = open_file(path = "avE-R11-S8R1-P6.dat")
E11S8R1P8 = open_file(path = "avE-R11-S8R1-P8.dat")
E11S6R1P2 = open_file(path = "avE-R11-S6R1-P2.dat")
E11S10R1P2 = open_file(path = "avE-R11-S10R1-P2.dat")
E21S8R1P1 = open_file(path = "avE-R21-S8R1-P1.dat")
E21S8R1P2 = open_file(path = "avE-R21-S8R1-P2.dat")
E21S8R1P4 = open_file(path = "avE-R21-S8R1-P4.dat")
E21S8R1P6 = open_file(path = "avE-R21-S8R1-P6.dat")
E21S8R1P8 = open_file(path = "avE-R21-S8R1-P8.dat")
E21S6R1P2 = open_file(path = "avE-R21-S6R1-P2.dat")
E21S10R1P2 = open_file(path = "avE-R21-S10R1-P2.dat")

hE11S8R1P1 = open_file(path = "avE-R11-S8I4R1-P1-r.dat")
hE11S8R1P2 = open_file(path = "avE-R11-S8I4R1-P2-r.dat")
hE11S8R1P3 = open_file(path = "avE-R11-S8I4R1-P3-r.dat")
hE11S6R1P2 = open_file(path = "avE-R11-S6I3R1-P2-r.dat")
hE11S10R1P2 = open_file(path = "avE-R11-S10I5R1-P2-r.dat")
hE21S8R1P1 = open_file(path = "avE-R21-S8I4R1-P1-r.dat")
hE21S8R1P2 = open_file(path = "avE-R21-S8I4R1-P2-r.dat")
hE21S8R1P3 = open_file(path = "avE-R21-S8I4R1-P3-r.dat")
hE21S6R1P2 = open_file(path = "avE-R21-S6I3R1-P2-r.dat")
hE21S10R1P2 = open_file(path = "avE-R21-S10I5R1-P2-r.dat")

# %%
blue = sns.color_palette("Blues_d", n_colors=3)
red=sns.color_palette("Reds_d", n_colors=3)
orange=sns.color_palette("Oranges_d", n_colors=3)
green=sns.color_palette("Greens_d", n_colors=3)
sns.palplot(blue), sns.palplot(red), sns.palplot(orange), sns.palplot(green)
# Out:
# (None, None, None, None)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

sns.set(context="paper", style="white")
sns.set_style("ticks", {"xtick.major.size": 20, "ytick.major.size": 20})
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20,10), squeeze=False)

axis_font = {'fontname':'Arial', 'size':'20'}
     
x0=np.arange(2000)
y0=[0.5]*2000

#1,1 plot
ax1 = axs[0][0]
ax1.set_title(r"(a1) R11, $N_S$=8",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax1.set_ylim([0,1])
ax1.set_xscale("log")
x1=E11S8R1P1[:,0]
y1=E11S8R1P1[:,3]
x2=E11S8R1P2[:,0]
y2=E11S8R1P2[:,3]
x3=E11S8R1P4[:,0]
y3=E11S8R1P4[:,3]
x5=E11S8R1P8[:,0]
y5=E11S8R1P8[:,3]
ax1.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax1.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$P=1$")
ax1.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$P=2$")
ax1.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$P=4$")
ax1.plot(x5, y5, '-', ms=8, color=orange[1], linewidth=3, label="$P=8$")
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_xlabel('$T$',**axis_font)
ax1.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax1.legend(loc="lower right", fontsize="large")
ax1.tick_params(axis='both',labelsize=16)


#2,1 plot
ax2 = axs[0][1]
ax2.set_title("(b1) R11, P=2",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax2.set_ylim([0,1])
ax2.set_xscale("log")
x1=E11S6R1P2[:,0]
y1=E11S6R1P2[:,3]
x2=E11S8R1P2[:,0]
y2=E11S8R1P2[:,3]
x3=E11S10R1P2[:,0]
y3=E11S10R1P2[:,3]
ax2.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax2.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$N_S=6$")
ax2.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$N_S=8$")
ax2.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$N_S=10$")
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$T$',**axis_font)
ax2.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax2.legend(loc="lower right", fontsize="large")
ax2.tick_params(axis='both',labelsize=16)


#1,2 plot
ax3 = axs[0][2]
ax3.set_title(r"(c1) R21, $N_S$=8",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax3.set_ylim([0,1])
ax3.set_xscale("log")
x1=E21S8R1P1[:,0]
y1=E21S8R1P1[:,3]
x2=E21S8R1P2[:,0]
y2=E21S8R1P2[:,3]
x3=E21S8R1P4[:,0]
y3=E21S8R1P4[:,3]
x5=E21S8R1P8[:,0]
y5=E21S8R1P8[:,3]
ax3.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax3.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$P=1$")
ax3.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$P=2$")
ax3.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$P=4$")
ax3.plot(x5, y5, '-', ms=8, color=orange[1], linewidth=3, label="$P=8$")
# Make the y-axis label, ticks and tick labels match the line color.
ax3.set_xlabel('$T$',**axis_font)
ax3.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax3.legend(loc="lower right", fontsize="large")
ax3.tick_params(axis='both',labelsize=16)


#2,2 plot
ax4 = axs[0][3]
ax4.set_title("(d1) R21, P=2",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax4.set_ylim([0,1])
ax4.set_xscale("log")
x1=E21S6R1P2[:,0]
y1=E21S6R1P2[:,3]
x2=E21S8R1P2[:,0]
y2=E21S8R1P2[:,3]
x3=E21S10R1P2[:,0]
y3=E21S10R1P2[:,3]
ax4.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax4.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$N_S=6$")
ax4.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$N_S=8$")
ax4.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$N_S=10$")
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$T$',**axis_font)
ax4.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax4.legend(loc="lower right", fontsize="large")
ax4.tick_params(axis='both',labelsize=16)


########################################################################

x0=np.arange(2000)
y0=[0.5]*2000

#1,1 plot
ax1 = axs[1][0]
ax1.set_title(r"(a2) R11, $N_S$=8",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax1.set_ylim([0,1.02])
ax1.set_xscale("log")
x1=hE11S8R1P1[:,0]
y1=hE11S8R1P1[:,3]
x2=hE11S8R1P2[:,0]
y2=hE11S8R1P2[:,3]
x3=hE11S8R1P3[:,0]
y3=hE11S8R1P3[:,3]
ax1.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax1.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$P=1$")
ax1.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$P=2$")
ax1.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$P=3$")
ax1.set_xlabel('$T$',**axis_font)
ax1.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax1.legend(loc="lower right", fontsize="large")
ax1.tick_params(axis='both',labelsize=16)


#2,1 plot
ax2 = axs[1][1]
ax2.set_title("(b2) R11, P=2",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax2.set_ylim([0,1])
ax2.set_xscale("log")
x1=hE11S6R1P2[:,0]
y1=hE11S6R1P2[:,3]
x2=hE11S8R1P2[:,0]
y2=hE11S8R1P2[:,3]
x3=hE11S10R1P2[:,0]
y3=hE11S10R1P2[:,3]
ax2.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax2.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$N_S=6$")
ax2.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$N_S=8$")
ax2.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$N_S=10$")
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$T$',**axis_font)
ax2.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax2.legend(loc="lower right", fontsize="large")
ax2.tick_params(axis='both',labelsize=16)


#1,2 plot
ax3 = axs[1][2]
ax3.set_title(r"(c2) R21, $N_S$=8",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax3.set_ylim([0,1.02])
ax3.set_xscale("log")
x1=hE21S8R1P1[:,0]
y1=hE21S8R1P1[:,3]
x2=hE21S8R1P2[:,0]
y2=hE21S8R1P2[:,3]
x3=hE21S8R1P3[:,0]
y3=hE21S8R1P3[:,3]
ax3.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax3.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$P=1$")
ax3.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$P=2$")
ax3.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$P=3$")
ax3.set_xlabel('$T$',**axis_font)
ax3.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax3.legend(loc="lower right", fontsize="large")
ax3.tick_params(axis='both',labelsize=16)


#2,2 plot
ax4 = axs[1][3]
ax4.set_title("(d2) R21, P=2",fontsize="x-large",loc="right",y=1,fontweight ="bold")
ax4.set_ylim([0,1])
ax4.set_xscale("log")
x1=hE21S6R1P2[:,0]
y1=hE21S6R1P2[:,3]
x2=hE21S8R1P2[:,0]
y2=hE21S8R1P2[:,3]
x3=hE21S10R1P2[:,0]
y3=hE21S10R1P2[:,3]
ax4.plot(x0, y0, ':', ms=8, color='k', linewidth=3, label="_nolegend_")
ax4.plot(x1, y1, '-', ms=8, color=blue[1], linewidth=3, label="$N_S=6$")
ax4.plot(x2, y2, '-', ms=8, color=red[1], linewidth=3, label="$N_S=8$")
ax4.plot(x3, y3, '-', ms=8, color=green[1], linewidth=3, label="$N_S=10$")
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$T$',**axis_font)
ax4.set_ylabel(r'$\langle P_s/P \rangle$',**axis_font)
ax4.legend(loc="lower right", fontsize="large")
ax4.tick_params(axis='both',labelsize=16)


########################################################################

fig.tight_layout()
plt.savefig("fig6.pdf", dpi=300)
plt.show()
