# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
def open_file(path = "avP-R11-S10I5R5.dat"):
    data = []
    with open(path) as f:
        for l in f.readlines():
            line = (l.split())
            if(line[0][0]!='#'):
              line = list(map(float, line))
              data.append(line)
    data = np.array(data)
    return data

# %%
avP11 = open_file(path = "avP-R11-S10I5R5.dat")
avP12 = open_file(path = "avP-R12-S10I5R5.dat")
avP21 = open_file(path = "avP-R21-S10I5R5.dat")
avP22 = open_file(path = "avP-R22-S10I5R5.dat")
avQ11 = open_file(path = "avQ-R11-S10I5R5.dat")
avQ12 = open_file(path = "avQ-R12-S10I5R5.dat")
avQ21 = open_file(path = "avQ-R21-S10I5R5.dat")
avQ22 = open_file(path = "avQ-R22-S10I5R5.dat")

# %%
blue = sns.color_palette("Blues_d", n_colors=3)
red=sns.color_palette("Reds_d", n_colors=3)
orange=sns.color_palette("Oranges_d", n_colors=3)
green=sns.color_palette("Greens_d", n_colors=3)
sns.palplot(blue), sns.palplot(red), sns.palplot(orange), sns.palplot(green)
# Out:
# (None, None, None, None)

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

sns.set(context="paper", style="white")
sns.set_style("ticks", {"xtick.major.size": 20, "ytick.major.size": 20})
fig, axs = plt.subplots(ncols=4, nrows=4, figsize=(24,20), squeeze=False)

axis_font = {'fontname':'Arial', 'size':'20'}
              
#1,1 plot
ax1 = axs[0][0]
ax1.set_title("(a1) R11",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax1.set_yscale("log")
x=avP11[:,3]
y=avP11[:,1]
im=ax1.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax1)
ax1.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_xlabel('$q_R^{\mu}$',**axis_font)
ax1.set_ylabel('$p_R^{\mu}$',**axis_font)
ax1.tick_params(axis='both',labelsize=16)


#1,2 plot
ax2 = axs[0][1]
ax2.set_title("(b1) R11",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax2.set_yscale("log")
x=avP11[:,7]
y=avP11[:,1]
im=ax2.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax2)
ax2.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$m_S^{\mu}$',**axis_font)
ax2.set_ylabel('$p_R^{\mu}$',**axis_font)
ax2.tick_params(axis='both',labelsize=16)


#1,3 plot
ax3 = axs[0][2]
ax3.set_title("(c1) R11",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax3.set_yscale("log")
x=avP11[:,7]
y=avP11[:,3]
im=ax3.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax3)
ax3.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax3.set_xlabel('$m_S^{\mu}$',**axis_font)
ax3.set_ylabel('$q_R^{\mu}$',**axis_font)
ax3.tick_params(axis='both',labelsize=16)


#1,4 plot
ax4 = axs[0][3]
ax4.set_title("(d1) R11",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax4.set_yscale("log")
x=avQ11[:,2]
y=avQ11[:,0]
im=ax4.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax4)
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$q_{S}^{\mu\mu}$',**axis_font)
ax4.set_ylabel('$q_{R}^{\mu\mu}$',**axis_font)
ax4.tick_params(axis='both',labelsize=16)

########################################################################


#2,1 plot
ax1 = axs[1][0]
ax1.set_title("(a2) R12",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax1.set_yscale("log")
x=avP12[:,3]
y=avP12[:,1]
im=ax1.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax1)
ax1.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_xlabel('$q_R^{\mu}$',**axis_font)
ax1.set_ylabel('$p_R^{\mu}$',**axis_font)
ax1.tick_params(axis='both',labelsize=16)


#2,2 plot
ax2 = axs[1][1]
ax2.set_title("(b2) R12",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax2.set_yscale("log")
x=avP12[:,7]
y=avP12[:,1]
im=ax2.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax2)
ax2.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$m_S^{\mu}$',**axis_font)
ax2.set_ylabel('$p_R^{\mu}$',**axis_font)
ax2.tick_params(axis='both',labelsize=16)


#2,3 plot
ax3 = axs[1][2]
ax3.set_title("(c2) R12",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax3.set_yscale("log")
x=avP12[:,7]
y=avP12[:,3]
im=ax3.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax3)
ax3.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax3.set_xlabel('$m_S^{\mu}$',**axis_font)
ax3.set_ylabel('$q_R^{\mu}$',**axis_font)
ax3.tick_params(axis='both',labelsize=16)


#2,4 plot
ax4 = axs[1][3]
ax4.set_title("(d2) R12",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax4.set_yscale("log")
x=avQ12[:,2]
y=avQ12[:,0]
im=ax4.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax4)
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$q_{S}^{\mu\mu}$',**axis_font)
ax4.set_ylabel('$q_{R}^{\mu\mu}$',**axis_font)
ax4.tick_params(axis='both',labelsize=16)

########################################################################


#2,1 plot
ax1 = axs[2][0]
ax1.set_title("(a3) R21",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax1.set_yscale("log")
x=avP21[:,3]
y=avP21[:,1]
im=ax1.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax1)
ax1.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_xlabel('$q_R^{\mu}$',**axis_font)
ax1.set_ylabel('$p_R^{\mu}$',**axis_font)
ax1.tick_params(axis='both',labelsize=16)


#2,2 plot
ax2 = axs[2][1]
ax2.set_title("(b3) R21",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax2.set_yscale("log")
x=avP21[:,7]
y=avP21[:,1]
im=ax2.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax2)
ax2.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$m_S^{\mu}$',**axis_font)
ax2.set_ylabel('$p_R^{\mu}$',**axis_font)
ax2.tick_params(axis='both',labelsize=16)


#2,3 plot
ax3 = axs[2][2]
ax3.set_title("(c3) R21",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax3.set_yscale("log")
x=avP21[:,7]
y=avP21[:,3]
im=ax3.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax3)
ax3.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax3.set_xlabel('$m_S^{\mu}$',**axis_font)
ax3.set_ylabel('$q_R^{\mu}$',**axis_font)
ax3.tick_params(axis='both',labelsize=16)


#2,4 plot
ax4 = axs[2][3]
ax4.set_title("(d3) R21",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax4.set_yscale("log")
x=avQ21[:,2]
y=avQ21[:,0]
im=ax4.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax4)
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$q_{S}^{\mu\mu}$',**axis_font)
ax4.set_ylabel('$q_{R}^{\mu\mu}$',**axis_font)
ax4.tick_params(axis='both',labelsize=16)

########################################################################



#2,1 plot
ax1 = axs[3][0]
ax1.set_title("(a4) R22",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax1.set_yscale("log")
x=avP22[:,3]
y=avP22[:,1]
im=ax1.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax1)
ax1.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax1.set_xlabel('$q_R^{\mu}$',**axis_font)
ax1.set_ylabel('$p_R^{\mu}$',**axis_font)
ax1.tick_params(axis='both',labelsize=16)


#2,2 plot
ax2 = axs[3][1]
ax2.set_title("(b4) R22",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax2.set_yscale("log")
x=avP22[:,7]
y=avP22[:,1]
im=ax2.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax2)
ax2.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax2.set_xlabel('$m_S^{\mu}$',**axis_font)
ax2.set_ylabel('$p_R^{\mu}$',**axis_font)
ax2.tick_params(axis='both',labelsize=16)


#2,3 plot
ax3 = axs[3][2]
ax3.set_title("(c4) R22",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax3.set_yscale("log")
x=avP22[:,7]
y=avP22[:,3]
im=ax3.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax3)
ax3.plot(x, y, 'o', ms=8, color=blue[0])
# Make the y-axis label, ticks and tick labels match the line color.
ax3.set_xlabel('$m_S^{\mu}$',**axis_font)
ax3.set_ylabel('$q_R^{\mu}$',**axis_font)
ax3.tick_params(axis='both',labelsize=16)


#2,4 plot
ax4 = axs[3][3]
ax4.set_title("(d4) R22",fontsize='x-large',loc='right',y=1,fontweight ="bold")
#ax4.set_yscale("log")
x=avQ22[:,2]
y=avQ22[:,0]
im=ax4.hist2d(x,y, bins=(10,10), cmap = plt.cm.Reds)
fig.colorbar(im[3], ax=ax4)
# Make the y-axis label, ticks and tick labels match the line color.
ax4.set_xlabel('$q_{S}^{\mu\mu}$',**axis_font)
ax4.set_ylabel('$q_{R}^{\mu\mu}$',**axis_font)
ax4.tick_params(axis='both',labelsize=16)

########################################################################



fig.tight_layout()
plt.savefig("fig4.pdf", dpi=300)
plt.show()
